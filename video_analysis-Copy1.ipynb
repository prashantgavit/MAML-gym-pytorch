# %%
import io
import os
import base64
from IPython.display import HTML

# %%
def show_video(video_path):
    if not os.path.exists(video_path):
        raise FileNotFoundError(f"{video_path} does not exist")

    video_encoded = base64.b64encode(open(video_path, "rb").read()).decode("ascii")
    return HTML(f"""
    <video width="640" height="480" controls>
        <source src="data:video/mp4;base64,{video_encoded}" type="video/mp4">
    </video>
    """)

import glob

# %%
video_files = glob.glob('./video/openaigym.video.0.561332.video000000.mp4')
video_files.sort()  # Optional: show latest

if video_files:
    display(show_video(video_files[0]))
else:
    print("No video file found.")
# Out:
#     <video width="640" height="480" controls>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>
